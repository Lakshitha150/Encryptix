# %% [markdown]
# <a href="https://colab.research.google.com/github/Lakshitha150/Encryptix/blob/main/Movie_Genre_Classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import shutil

# Source file paths (assuming they are in the current Colab directory)
source_file1 = '/content/drive/MyDrive/Movie_classification/test_data1.txt'
source_file2 = '/content/drive/MyDrive/Movie_classification/train_data1.txt'

# Destination directory in your Drive
destination_dir = '/content/'

# Copy the files
shutil.copy(source_file1, destination_dir)
shutil.copy(source_file2, destination_dir)

print('Files copied successfully!')
# Out:
# Files copied successfully!

# %%
from sklearn.feature_extraction.text import TfidfVectorizer


corpus = [
    'This is the first document.',
    'This document is the second document.',
    'And this is the third one.',
    'Is this the first document?',
]

# %%
v = TfidfVectorizer()
transformed_output = v.fit_transform(corpus)
print(v.vocabulary_)
# Out:
# {'this': 8, 'is': 3, 'the': 6, 'first': 2, 'document': 1, 'second': 5, 'and': 0, 'third': 7, 'one': 4}

# %%
all_feature_names = v.get_feature_names_out()

for word in all_feature_names:
    indx = v.vocabulary_.get(word)
    print(f"{word} {v.idf_[indx]}")
#
# Out:
# and 1.916290731874155
# document 1.2231435513142097
# first 1.5108256237659907
# is 1.0
# one 1.916290731874155
# second 1.916290731874155
# the 1.0
# third 1.916290731874155
# this 1.0

# %%
corpus[:2]
# Out:
# ['This is the first document.', 'This document is the second document.']

# %%
transformed_output.toarray()[:2]
# Out:
# array([[0.        , 0.46979139, 0.58028582, 0.38408524, 0.        ,
#         0.        , 0.38408524, 0.        , 0.38408524],
#        [0.        , 0.6876236 , 0.        , 0.28108867, 0.        ,
#         0.53864762, 0.28108867, 0.        , 0.28108867]])

# %%
# importing pandas library
import pandas as pd

# read txt file
movie_classification = pd.read_csv("train_data1.txt", sep=' \:\:\: ', header=None, engine='python')

# adding column headings
movie_classification.columns = ['ID','TITLE','GENRE','DESCRIPTION']

# store dataframe into csv file
movie_classification.to_csv('train_data1.csv',index = None)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-b1826548a07c> in <cell line: 5>()
#       3
#       4 # read txt file
# ----> 5 movie_classification = pd.read_csv("train_data1.txt", sep=' \:\:\: ', header=None, engine='python')
#       6
#       7 # adding column headings
#
# ...

# %%
# importing pandas library
import pandas as pd

# read txt file
websites = pd.read_csv("test_data1.txt", sep=' \:\:\: ', header=None, engine='python')

# adding column headings
websites.columns = ['ID','TITLE','DESCRIPTION']

# store dataframe into csv file
websites.to_csv('test_data1.csv',index = None)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-bc72da58b49c> in <cell line: 5>()
#       3
#       4 # read txt file
# ----> 5 websites = pd.read_csv("test_data1.txt", sep=' \:\:\: ', header=None, engine='python')
#       6
#       7 # adding column headings
#
# ...

# %%
df1 = pd.read_csv('train_data1.csv')
print(df1.shape)
df1.head()
# Out:
# (54214, 4)
#    ID                             TITLE     GENRE  \
# 0   1      Oscar et la dame rose (2009)     drama
# 1   2                      Cupid (1997)  thriller
# 2   3  Young, Wild and Wonderful (1980)     adult
# 3   4             The Secret Sin (1915)     drama
# 4   5            The Unrecovered (2007)     drama
#
#                                          DESCRIPTION
# 0  Listening in to a conversation between his doc...
# 1  A brother and sister with a past incestuous re...
# 2  As the bus empties the students for their fiel...
# 3  To help their unemployed father make ends meet...
# 4  The film's title refers not only to the un-rec...

# %%
df1['GENRE'].value_counts()
# Out:
# GENRE
# drama          13613
# documentary    13096
# comedy          7447
# short           5073
# horror          2204
# thriller        1591
# action          1315
# western         1032
# reality-tv       884
# family           784
# adventure        775
# music            731
# romance          672
# sci-fi           647
# adult            590
# crime            505
# animation        498
# sport            432
# talk-show        391
# fantasy          323
# mystery          319
# musical          277
# biography        265
# history          243
# game-show        194
# news             181
# war              132
# Name: count, dtype: int64

# %%
df2 = pd.read_csv('test_data1.csv')
print(df2.shape)
df2.head()
# Out:
# (100, 3)
#    ID                        TITLE  \
# 0   1         Edgar's Lunch (1998)
# 1   2     La guerra de papá (1977)
# 2   3  Off the Beaten Track (2010)
# 3   4       Meu Amigo Hindu (2015)
# 4   5            Er nu zhai (1955)
#
#                                          DESCRIPTION
# 0  L.R. Brane loves his life - his car, his apart...
# 1  Spain, March 1964: Quico is a very naughty chi...
# 2  One year in the life of Albin and his family o...
# 3  His father has died, he hasn't spoken with his...
# 4  Before he was known internationally as a marti...

# %%
df1['genre_num'] = df1['GENRE'].map({
    'drama': 1,
    'documentary': 2,
    'comedy': 3,
    'thriller': 4,
    'horror': 5,
    'short': 6,
    'adult': 7,
    'sci-fi': 8,
    'family': 9,
    'talk-show': 10,
    'action': 11,
    'reality-tv': 12,
    'crime': 13,
    'fantasy': 14,
    'animation': 15,
    'sport': 16,
    'music': 17,
    'adventure': 18,
    'western': 19,
    'mystery': 20,
    'musical': 21,
    'biography': 22,
    'history': 23,
    'game-show': 24,
    'news': 25,
    'war': 26,
    'romance': 27
})

df1.head()
# Out:
#    ID                             TITLE     GENRE  \
# 0   1      Oscar et la dame rose (2009)     drama
# 1   2                      Cupid (1997)  thriller
# 2   3  Young, Wild and Wonderful (1980)     adult
# 3   4             The Secret Sin (1915)     drama
# 4   5            The Unrecovered (2007)     drama
#
#                                          DESCRIPTION  genre_num
# 0  Listening in to a conversation between his doc...          1
# 1  A brother and sister with a past incestuous re...          4
# 2  As the bus empties the students for their fiel...          7
# 3  To help their unemployed father make ends meet...          1
# 4  The film's title refers not only to the un-rec...          1

# %%
#y_train = df1['genre_num']
#X_train = df1.drop('DESCRIPTION', axis = 1)
#y_test = df2['genre_num']
#X_test = df2.drop('DESCRIPTION', axis = 1)

# %%
import sklearn
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df1["DESCRIPTION"], df1['genre_num'], test_size=0.2, random_state=42, stratify=df1['genre_num'])

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (43371,)
# (10843,)

# %%
y_train.value_counts()
# Out:
# genre_num
# 1     10890
# 2     10477
# 3      5957
# 6      4058
# 5      1763
# 4      1273
# 11     1052
# 19      826
# 12      707
# 9       627
# 18      620
# 17      585
# 27      538
# 8       518
# 7       472
# 13      404
# 15      398
# 16      346
# 10      313
# 14      258
# 20      255
# 21      222
# 22      212
# 23      194
# 24      155
# 25      145
# 26      106
# Name: count, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

clf = Pipeline([
    ('vectorizer_tfidf', TfidfVectorizer()),
     ('knn',KNeighborsClassifier())])
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred))
